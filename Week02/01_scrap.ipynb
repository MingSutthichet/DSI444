# %% [markdown]
# # 01_scrap
# - scrapping data from newsdata.io and upload to DataPlatform

# %% [markdown]
# ## Getting data from scrapy

# %%
import requests

url_get = requests.get('https://github.com/MingSutthichet/DSI310-Week2')
print(url_get)
# Out:
# <Response [200]>
