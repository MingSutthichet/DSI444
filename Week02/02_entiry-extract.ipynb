# %% [markdown]
# # 02_entiry-extract
# - entity extraction from news description using trasnformer `Davlan/xlm-roberta-base-ner-hrl`

# %% [markdown]
# ### read stored data from DataPlatform

# %%
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_raw_id = 106
dir_process_id = 107

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_raw_id, name='standard_education.json'))
meta
# Out:
# {'owner': 'sutthichet',
#  'human_size': '300.36 KB',
#  'name': 'standard_education.json',
#  'description': '-',
#  'directory': 106,
#  'path': 'sutthichet/DSI310-01/rawData/standard_education.json'}

# %%
data = json.load(fp)
data
# Out:
# {'title': {'0': ' ชมคลิป: จากรปภ. สู่ ปลัดอำเภอ การต่อสู้ 11 ปี ของคนธรรมดา | THE STANDARD NOW ',
#   '1': ' กทม. ใช้ 54 โรงเรียนในสังกัด นำร่องพื้นที่นวัตกรรมการศึกษา ลดความเหลื่อมล้ำ ให้อิสระการบริหารงาน ',
#   '2': ' เปิดชื่อ ‘Business School’ โรงเรียนสอนธุรกิจ ที่ดีที่สุดประจำปี 2022 มีที่ไหนตรงใจบ้างสำหรับผู้ที่กำลังจะไปเรียนต่อ ',
#   '3': ' ประวิตร กล่าวถ้อยแถลงเวที UN โชว์วิสัยทัศน์ประเด็นการศึกษา ย้ำไทยเน้นเรียนออนไลน์อย่างครอบคลุม เสมอภาค ไม่มีค่าใช้จ่าย ',
#   '4': ' คลังห่วงกู้ยืมเงิน กยศ. ไม่ต้องจ่ายดอกเบี้ย-เบี้ยปรับ กระทบวินัยการชำระหนี้ เตรียมแจงข้อเท็จจริงต่อวุฒิสภา ',
#   '5': ' ‘ธงชัย วินิจจะกูล’ รับตำแหน่งศาสตราจารย์รับเชิญ วิทยาลัยนานาชาติปรีดี พนมยงค์ ประจำปี 2565 ',
#   '6': ' ชัชชาติ เปิดงาน Saturday School BIG DAY 2022 ทุกที่เป็นโรงเรียนได้ การเรียนรู้ไม่ได้หยุดแค่รั้วโรงเรียน ',
#   '7': ' YouTube ปล่อยฟีเจอร์ใหม่ด้านการศึกษา ช่วยให้ผู้เรียนสามารถโฟกัสกับเนื้อหาโดยไม่มีโฆษณามาคั่น ',
# ...

# %%
df = pd.json_normalize(data)

# %%
#df = pd.DataFrame(df2)

# %% [markdown]
# ### write DataNode to DataPlatform

# %%
datanode.write(df=df, directory=dir_process_id, name="data", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_raw_id, name='standard_education.json')])
# Out:
# File data.parquet alrady exists, do you want to replace y/n :  y
# {'sucess': True,
#  'file_id': 217,
#  'path': 'sutthichet/DSI310-01/processData/data.parquet',
#  'lineage': True}
